# %% [markdown]
# # Péndulo Doble
# Para el punto 3, hallaremos usando `smypy` las ecuaciones de movimiento del péndulo invertido, para luego resolverlas numéricamente usando de `scipy.integrate` el método `odeint` (RK4).

# %%
# Importe de librerías
import numpy as np
import sympy as smp
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import PillowWriter

from sympy.physics.mechanics import *
init_vprinting(pretty_print=True)

# %% [markdown]
# ## Solución numérica sin linealización
# Inicialmente definimos las variables independientes, según el dibujo :)

# %%
t, g, m1, m2, L1, L2 = smp.symbols('t, g, m_1, m_2, L_1, L_2')

# %% [markdown]
# $\theta_1$ and $\theta_2$ son functions del tiempo, para las cuales solucionaremos las EDOs más adelante.

# %%
th1, th2 = smp.symbols(r'\theta_1, \theta_2', cls=smp.Function)
th1 = th1(t)
th2 = th2(t)

th1
# Out:
# \theta₁

# %% [markdown]
# También definimos las primeras y segundas derivadas de ambos ángulos.

# %%
# Derivadas de las coordenadas angulares
dth1 = smp.diff(th1, t)
dth2 = smp.diff(th2, t)
d2th1 = smp.diff(dth1, t)
d2th2 = smp.diff(dth2, t)

d2th2
# Out:
# \thëta₂

# %% [markdown]
# También definimos $x_1$, $y_1$, $x_2$, y $y_2$ en términos de los ángulos $\theta_1$ y $\theta_2$, para poder hacer la animación más adelante y para calcular fácilmente las energías del sistema.
#
# Las coordenadas cartesianas a partir de las coordenadas polares definidas en la imagen arriba se pueden calcular como, para la primera masa:
#
# $$x_1 = L_1 \sin(\theta_1)$$
# $$y_1 = -L_1 \cos(\theta_1)$$
#
# mientras que, para la segunda masa son:
#
# $$ x_2 = L_1 \sin(\theta_1) + L_2 \sin(\theta_2) $$
# $$ y_2 = -L_1 \cos(\theta_1) - L_2 \cos(\theta_2) $$

# %%
# Coordenadas cartesianas
x1 = L1*smp.sin(th1)
y1 = -L1*smp.cos(th1)
x2 = L1*smp.sin(th1)+L2*smp.sin(th2)
y2 = -L1*smp.cos(th1)-L2*smp.cos(th2)

# %% [markdown]
# Para las hallar las dos ecuaciones de Euler-Lagrange (ecuaciones EL), debemos hallar el lagrangiano $L=T-V$ en términos de las coordenadas $\theta_i$ y las velocidades angulares $\omega_i := \dot{\theta}_i$.
#
# En particular, la energía cinética del sistema es la suma de las energías cinéticas de ambas masas:
#
# $$ T = T_1 + T_2 = \frac{1}{2} m_1 (\dot{x_1}^2 + \dot{y_1}^2) + \frac{1}{2} m_2 (\dot{x_2}^2 + \dot{y_2}^2) $$
#
# Mientras que, definiendo el cero de energía potencial en como se muestra en la figura, la energía potencial del sistema es:
#
# $$ V = V_1 + V_2 = m_1 g y_1 + m_2 g y_2$$

# %%
# Cinética
T1 = smp.Rational(1,2) * m1 * (smp.diff(x1, t)**2 + smp.diff(y1, t)**2)
T2 = smp.Rational(1,2) * m2 * (smp.diff(x2, t)**2 + smp.diff(y2, t)**2)
T = T1+T2
# Potencial
V1 = m1*g*y1
V2 = m2*g*y2
V = V1 + V2
# Lagrangiano
L = T-V

# %%
print(smp.latex(L.simplify()))
# Out:
# \frac{L_{1}^{2} m_{1} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2}}{2} + L_{1} g m_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} + g m_{2} \left(L_{1} \cos{\left(\theta_{1}{\left(t \right)} \right)} + L_{2} \cos{\left(\theta_{2}{\left(t \right)} \right)}\right) + \frac{m_{2} \left(L_{1}^{2} \left(\frac{d}{d t} \theta_{1}{\left(t \right)}\right)^{2} + 2 L_{1} L_{2} \cos{\left(\theta_{1}{\left(t \right)} - \theta_{2}{\left(t \right)} \right)} \frac{d}{d t} \theta_{1}{\left(t \right)} \frac{d}{d t} \theta_{2}{\left(t \right)} + L_{2}^{2} \left(\frac{d}{d t} \theta_{2}{\left(t \right)}\right)^{2}\right)}{2}

# %%
L
# Out:
#                                                                       ⎛  2
#                                                                    m₁⋅⎝L₁ ⋅sin
# L₁⋅g⋅m₁⋅cos(\theta₁) - g⋅m₂⋅(-L₁⋅cos(\theta₁) - L₂⋅cos(\theta₂)) + ───────────
#
#
# 2                 2     2    2                 2⎞      ⎛
#  (\theta₁)⋅\thėta₁  + L₁ ⋅cos (\theta₁)⋅\thėta₁ ⎠   m₂⋅⎝(L₁⋅sin(\theta₁)⋅\th
# ───────────────────────────────────────────────── + ──────────────────────────
#                   2
#
#                              2
# ėta₁ + L₂⋅sin(\theta₂)⋅\thėta₂)  + (L₁⋅cos(\theta₁)⋅\thėta₁ + L₂⋅cos(\theta
# ──────────────────────────────────────────────────────────────────────────────
#                              2
#
#       2⎞
# ₂)⋅\thėta₂) ⎠
# ────────

# %% [markdown]
# Ahora, las ecuaciones EL (que son dos, porque hay dos cuerpos), se hallan usando la condición necesaria de optimalidad de primer orden como se muestra a continuación:
#
# $$\frac{\partial L}{\partial \theta_1} - \frac{d}{dt}\frac{\partial L}{\partial \dot{\theta_1}} = 0$$
# $$\frac{\partial L}{\partial \theta_2} - \frac{d}{dt}\frac{\partial L}{\partial \dot{\theta_2}} = 0$$

# %%
# Ecuaciones EL
EL1 = smp.Eq(smp.diff(L, th1) - smp.diff(smp.diff(L, dth1), t), 0).simplify()
EL2 = smp.Eq(smp.diff(L, th2) - smp.diff(smp.diff(L, dth2), t), 0).simplify()

EL1
# Out:
#    ⎛                                                                    2
# L₁⋅⎝L₁⋅m₁⋅\thëta₁ + L₁⋅m₂⋅\thëta₁ + L₂⋅m₂⋅sin(\theta₁ - \theta₂)⋅\thėta₂  +
#
#                                                                           ⎞
#  L₂⋅m₂⋅cos(\theta₁ - \theta₂)⋅\thëta₂ + g⋅m₁⋅sin(\theta₁) + g⋅m₂⋅sin(\theta₁)
#
#
# ⎠ = 0

# %%
EL2
# Out:
#       ⎛                                 2
# L₂⋅m₂⋅⎝L₁⋅sin(\theta₁ - \theta₂)⋅\thėta₁  - L₁⋅cos(\theta₁ - \theta₂)⋅\thëta
#
#                              ⎞
# ₁ - L₂⋅\thëta₂ - g⋅sin(\theta₂)⎠ = 0

# %% [markdown]
# Notemos que ambas ecuaciones EL son lineales en las segundas derivadas de $\theta_1$ y $\theta_2$. Para la aplicación de `odeint` requerimos despejar estas derivadas de segundo orden.

# %%
sols = smp.solve([EL1, EL2], (d2th1, d2th2), simplify=False, rational=False)
sols
# Out:
# ⎧                 ⎛                                   2                 ⎞
# ⎪           L₂⋅m₂⋅⎝- L₁⋅sin(\theta₁ - \theta₂)⋅\thėta₁  + g⋅sin(\theta₂)⎠⋅cos
# ⎨\thëta₁: - ─────────────────────────────────────────────────────────────────
# ⎪                                      2
# ⎩                          L₁⋅L₂⋅m₂⋅cos (\theta₁ - \theta₂) - L₂⋅(L₁⋅m₁ + L₁⋅m
#
#                         ⎛                                      2
# (\theta₁ - \theta₂)   L₂⋅⎝- L₂⋅m₂⋅sin(\theta₁ - \theta₂)⋅\thėta₂  - g⋅m₁⋅sin(
# ─────────────────── - ────────────────────────────────────────────────────────
#                                                 2
# ₂)                                  L₁⋅L₂⋅m₂⋅cos (\theta₁ - \theta₂) - L₂⋅(L₁⋅
#
#                           ⎞              ⎛
# \theta₁) - g⋅m₂⋅sin(\theta₁)⎠           L₁⋅⎝- L₂⋅m₂⋅sin(\theta₁ - \theta₂)⋅\th
# ────────────────────────────, \thëta₂: ──────────────────────────────────────
#                                                                              2
# m₁ + L₁⋅m₂)                                                      L₁⋅L₂⋅m₂⋅cos
#
#   2                                        ⎞
# ėta₂  - g⋅m₁⋅sin(\theta₁) - g⋅m₂⋅sin(\theta₁)⎠⋅cos(\theta₁ - \theta₂)   (L₁⋅m
# ───────────────────────────────────────────────────────────────────── + ──────
#
# (\theta₁ - \theta₂) - L₂⋅(L₁⋅m₁ + L₁⋅m₂)
#
#         ⎛                                   2                 ⎞⎫
# ₁ + L₁⋅m₂)⋅⎝- L₁⋅sin(\theta₁ - \theta₂)⋅\thėta₁  + g⋅sin(\theta₂)⎠⎪
# ─────────────────────────────────────────────────────────────────⎬
#              2                                                 ⎪
#  L₁⋅L₂⋅m₂⋅cos (\theta₁ - \theta₂) - L₂⋅(L₁⋅m₁ + L₁⋅m₂)         ⎭

# %% [markdown]
# Ahora, `sols` es un diccionario que contiene dos ecuaciones de la forma:
#
# * $\frac{d^2 \theta_1}{dt^2} = ...$
# * $\frac{d^2 \theta_2}{dt^2} = ...$
#
# Que son dos EDOs de segundo orden. En python solo se pueden solucionar sistemas de EDOs de primer orden. No obstante, cualquier ecuación de segundo orden se puede reducir a dos ecuaciones de primer orden aplicando el siguiente truco:
#
# 1. Se define $z_1 = d\theta_1/dt$ y $z_2=d\theta_2/dt$
# 2. Luego, se tiene que $dz_1/dt = d^2\theta_1/dt^2$ y $dz_2/dt = d^2\theta_2/dt^2$
#
# De modo que, aplicando este truco, obtenemos un sistema de cuatro ecuaciones de primer orden:
#
# * $d z_1/dt = ...$
# * $d\theta_1/dt = z_1$
# * $d z_2/dt = ...$
# * $d\theta_2/dt = z_1$
#
# Ahora, dado que hasta ahora tenemos ecuaciones simbólicas de python, necesitamos convertir estas expresiones a funciones numéricas instanciables para meterlas en el solver `odeint`. Para ello usamos `smp.lambdify` como se muestra:

# %%
# Conversión de expresiones simbólicas a funciones
dz1dt_f = smp.lambdify((t,g,m1,m2,L1,L2,th1,th2,dth1,dth2), sols[d2th1])
dz2dt_f = smp.lambdify((t,g,m1,m2,L1,L2,th1,th2,dth1,dth2), sols[d2th2])
dthe1dt_f = smp.lambdify(dth1, dth1)
dthe2dt_f = smp.lambdify(dth2, dth2)

# %% [markdown]
# Ahora, debemos definir $\vec{S} = (\theta_1, z_1, \theta_2, z_2)$. Si vamos a usar un solver en python, necesitamos crear una función que tome el vector $\vec{S}$ y el tiempo $t$ and y retorne $d\vec{S}/dt$. En otras palabras, debemos definir $d\vec{S}/dt (\vec{S}, t)$.
#
# Así, nuestro sistema de EDOs viene completamente especificado por $d\vec{S}/dt$ y depende solo de $\vec{S}$ y $t$.

# %%
def dSdt(S, t, g, m1, m2, L1, L2):
    the1, z1, the2, z2 = S
    return [
        dthe1dt_f(z1),
        dz1dt_f(t, g, m1, m2, L1, L2, the1, the2, z1, z2),
        dthe2dt_f(z2),
        dz2dt_f(t, g, m1, m2, L1, L2, the1, the2, z1, z2),
    ]

# %% [markdown]
# Finalmente, antes de resolver el sistema de EDOS, necesitamos especificar las condiciones iniciales del sistema. El vector de condiciones iniciales tiene la forma:
#
# $$\text{ics} = \begin{pmatrix} \theta_1 \\ \dot{\theta_1} \\ \theta_2 \\ \dot{\theta_2} \end{pmatrix}$$

# %%
ics = [1, -3, -1, 5]

# %% [markdown]
# Y finalmente, resolvemos el sistema de EDOs usando `odeint` en el intervalo $t \in [0,40]$, con los parámetros especificados.

# %%
t_v = np.linspace(0, 40, 1001)
g_v = 9.81
m1_v = 2
m2_v = 1
L1_v = 2
L2_v = 1
ans = odeint(dSdt, y0=ics, t=t_v, args=(g_v, m1_v, m2_v, L1_v, L2_v))

# %%
ans.T
# Out:
# array([[ 1.00000000e+00,  8.74139060e-01,  7.33333063e-01, ...,
#         -2.58662075e+00, -2.59465079e+00, -2.59731306e+00],
#        [-3.00000000e+00, -3.31025173e+00, -3.75998052e+00, ...,
#         -2.66852387e-01, -1.34231764e-01,  1.85058791e-03],
#        [-1.00000000e+00, -7.82776845e-01, -5.21398556e-01, ...,
#          3.09553632e+01,  3.09789250e+01,  3.10150090e+01],
#        [ 5.00000000e+00,  5.91440903e+00,  7.24155048e+00, ...,
#          4.33949669e-01,  7.44985269e-01,  1.05954113e+00]])

# %%
th1_v = ans.T[0]
dth1_v = ans.T[1]
th2_v = ans.T[2]
dth2_v = ans.T[3]

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"]
})

plt.figure()

plt.plot(t_v, th1_v, label=r'$\theta_1(t)$')
plt.plot(t_v, th2_v, label=r'$\theta_2(t)$')


plt.xlabel(r'$t [s]$')
plt.ylabel(r'Ángulos [rad]')
plt.title(r'$\theta_1$ y $\theta_2$ en función del tiempo $t$')
plt.legend()

plt.grid(True, color='lightgray')
plt.savefig('figures/nl-th1-vs-th2.pdf', format='pdf')

plt.show()

# %%
# Gráfica en el espacio de fases
plt.figure()

plt.plot(th1_v, dth1_v)

plt.xlabel(r'$\theta_1$ [rad]')
plt.ylabel(r'$\dot{\theta}_1$ [rad/s]')
plt.title(r'Trayectoria en el espacio de fases para $m_1$')

plt.grid(True, color='lightgray')
plt.savefig('figures/nl-phase-proyection-th1.pdf', format='pdf')
plt.show()

# %%
# Gráfica en el espacio de fases
plt.figure()

plt.plot(th2_v, dth2_v)

plt.xlabel(r'$\theta_2$ [rad]')
plt.ylabel(r'$\dot{\theta}_2$ [rad/s]')
plt.title(r'Trayectoria en el espacio de fases para $m_2$')

plt.grid(True, color='lightgray')
plt.savefig('figures/nl-phase-proyection-th2.pdf', format='pdf')
plt.show()

# %% [markdown]
# Por último, para hacer una animación de la dinámica del sistema, creamos una función que toma $\theta_1$ y $\theta_2$ y retorna la locación $(x,y)$ de ambas masas.

# %%
def get_cartesian(t, the1, the2, L1, L2):
    return (L1_v * np.sin(the1),
            -L1_v * np.cos(the1),
            L1_v * np.sin(the1) + L2_v * np.sin(the2),
            -L1_v * np.cos(the1) - L2_v * np.cos(the2))

x1_v, y1_v, x2_v, y2_v = get_cartesian(t_v, th1_v, th2_v, L1_v, L2_v)

# %% [markdown]
# Y luego creamos una animación!

# %%
def animate(i):
    ln1.set_data([0, x1_v[i], x2_v[i]], [0, y1_v[i], y2_v[i]])

fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_facecolor('k')
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ln1, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ax.set_ylim(-4,4)
ax.set_xlim(-4,4)
ani = animation.FuncAnimation(fig, animate, frames=1000, interval=50)
ani.save('gifs/nl-double-pendulum.gif', writer='pillow', fps=25)

# %% [markdown]
# # Linealización

# %%
lin1 = {smp.sin(th1) : th1, smp.cos(th1) : 1, smp.sin(th2) : th2, smp.cos(th2) : 1,
       dth1**2 : 0, dth2**2 : 0}
lin2 = {th1 * th2 : 0}

# %%
EL1_l = smp.expand(smp.expand_trig(EL1).subs(lin1).subs(lin2))
EL1_l
# Out:
#   2                2
# L₁ ⋅m₁⋅\thëta₁ + L₁ ⋅m₂⋅\thëta₁ + L₁⋅L₂⋅m₂⋅\thëta₂ + L₁⋅g⋅m₁⋅\theta₁ + L₁⋅g
#
#
# ⋅m₂⋅\theta₁ = 0

# %%
EL2_l = smp.expand(smp.expand_trig(EL2).subs(lin1).subs(lin2))
EL2_l
# Out:
#                       2
# -L₁⋅L₂⋅m₂⋅\thëta₁ - L₂ ⋅m₂⋅\thëta₂ - L₂⋅g⋅m₂⋅\theta₂ = 0

# %%
# Matriz de Masa
M = smp.Matrix([[L1**2 * (m1 + m2), m2*L1*L2],[m2*L1*L2, m2*L2**2]])
M
# Out:
# ⎡  2                    ⎤
# ⎢L₁ ⋅(m₁ + m₂)  L₁⋅L₂⋅m₂⎥
# ⎢                       ⎥
# ⎢                  2    ⎥
# ⎣  L₁⋅L₂⋅m₂      L₂ ⋅m₂ ⎦

# %%
K = smp.Matrix([[(m1 +m2)*g*L1, 0],[0, m2*g*L2]])
K
# Out:
# ⎡L₁⋅g⋅(m₁ + m₂)     0   ⎤
# ⎢                       ⎥
# ⎣      0         L₂⋅g⋅m₂⎦

# %%
TH = smp.Matrix([th1, th2])
TH
# Out:
# ⎡\theta₁⎤
# ⎢       ⎥
# ⎣\theta₂⎦

# %%
d2TH = TH.diff(t).diff(t)
d2TH
# Out:
# ⎡\thëta₁⎤
# ⎢       ⎥
# ⎣\thëta₂⎦

# %%
EQ_l = smp.Eq(M*d2TH, K*TH)
EQ_l
# Out:
# ⎡  2                                     ⎤
# ⎢L₁ ⋅(m₁ + m₂)⋅\thëta₁ + L₁⋅L₂⋅m₂⋅\thëta₂⎥   ⎡L₁⋅g⋅(m₁ + m₂)⋅\theta₁⎤
# ⎢                                        ⎥ = ⎢                      ⎥
# ⎢                        2               ⎥   ⎣   L₂⋅g⋅m₂⋅\theta₂    ⎦
# ⎣   L₁⋅L₂⋅m₂⋅\thëta₁ + L₂ ⋅m₂⋅\thëta₂    ⎦

# %%
sols_l = smp.solve([EL1_l, EL2_l], (d2th1, d2th2), simplify=False, rational=False)
sols_l
# Out:
# ⎧                         2     2                      2
# ⎪                    L₁⋅L₂ ⋅g⋅m₂ ⋅\theta₂            L₂ ⋅m₂⋅(-L₁⋅g⋅m₁⋅\theta₁
# ⎨\thëta₁: - ────────────────────────────────────── - ────────────────────────
# ⎪             2   2   2     2    ⎛  2        2   ⎞        2   2   2     2    ⎛
# ⎩           L₁ ⋅L₂ ⋅m₂  - L₂ ⋅m₂⋅⎝L₁ ⋅m₁ + L₁ ⋅m₂⎠      L₁ ⋅L₂ ⋅m₂  - L₂ ⋅m₂⋅⎝
#
#
# - L₁⋅g⋅m₂⋅\theta₁)           L₁⋅L₂⋅m₂⋅(-L₁⋅g⋅m₁⋅\theta₁ - L₁⋅g⋅m₂⋅\theta₁)
# ───────────────────, \thëta₂: ───────────────────────────────────────────── +
#   2        2   ⎞                   2   2   2     2    ⎛  2        2   ⎞
# L₁ ⋅m₁ + L₁ ⋅m₂⎠                 L₁ ⋅L₂ ⋅m₂  - L₂ ⋅m₂⋅⎝L₁ ⋅m₁ + L₁ ⋅m₂⎠      L
#
#          ⎛  2        2   ⎞           ⎫
#  L₂⋅g⋅m₂⋅⎝L₁ ⋅m₁ + L₁ ⋅m₂⎠⋅\theta₂   ⎪
#  ──────────────────────────────────────⎬
#  2   2   2     2    ⎛  2        2   ⎞⎪
# ₁ ⋅L₂ ⋅m₂  - L₂ ⋅m₂⋅⎝L₁ ⋅m₁ + L₁ ⋅m₂⎠⎭

# %%
# Conversión de expresiones simbólicas a funciones
dz1dt_lf = smp.lambdify((t,g,m1,m2,L1,L2,th1,th2,dth1,dth2), sols_l[d2th1])
dz2dt_lf = smp.lambdify((t,g,m1,m2,L1,L2,th1,th2,dth1,dth2), sols_l[d2th2])
dthe1dt_lf = smp.lambdify(dth1, dth1)
dthe2dt_lf = smp.lambdify(dth2, dth2)

# %%
def dSdt_l(S, t, g, m1, m2, L1, L2):
    the1, z1, the2, z2 = S
    return [
        dthe1dt_lf(z1),
        dz1dt_lf(t, g, m1, m2, L1, L2, the1, the2, z1, z2),
        dthe2dt_lf(z2),
        dz2dt_lf(t, g, m1, m2, L1, L2, the1, the2, z1, z2),
    ]

# %%
ans_l = odeint(dSdt_l, y0=ics, t=t_v, args=(g_v, m1_v, m2_v, L1_v, L2_v))

# %%
th1_lv = ans_l.T[0]
dth1_lv = ans_l.T[1]
th2_lv = ans_l.T[2]
dth2_lv = ans_l.T[3]

# %%
x1_lv, y1_lv, x2_lv, y2_lv = get_cartesian(t_v, th1_lv, th2_lv, L1_v, L2_v)

# %%
plt.figure()

plt.plot(t_v, th1_v, label=r'$\theta_1(t)$ NL')
plt.plot(t_v, th1_lv, label=r'$\theta_1(t)$ L')


plt.xlabel(r'$t [s]$')
plt.ylabel(r'Ángulos [rad]')
plt.title(r'Comparativa NL vs L')
plt.legend()

plt.grid(True, color='lightgray')
plt.savefig('figures/th1-l-vs-nl.pdf', format='pdf')
plt.show()

# %%
plt.figure()

plt.plot(t_v, th2_v, label=r'$\theta_2(t)$ NL')
plt.plot(t_v, th2_lv, label=r'$\theta_2(t)$ L')


plt.xlabel(r'$t [s]$')
plt.ylabel(r'Ángulos [rad]')
plt.title(r'Comparativa NL vs L')
plt.legend()

plt.grid(True, color='lightgray')
plt.savefig('figures/th2-l-vs-nl.pdf', format='pdf')
plt.show()

# %%
def animate_l(i):
    ln1.set_data([0, x1_lv[i], x2_lv[i]], [0, y1_lv[i], y2_lv[i]])

fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_facecolor('k')
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ln1, = plt.plot([], [], 'ro--', lw=3, markersize=8)
ax.set_ylim(-4,4)
ax.set_xlim(-4,4)
ani = animation.FuncAnimation(fig, animate, frames=1000, interval=50)
ani.save('gifs/l-double-pendulum.gif',writer='pillow',fps=25)

# %%
def animate_nl(i):
    ln1_nl.set_data([0, x1_v[i], x2_v[i]], [0, y1_v[i], y2_v[i]])

# Second pendulum animation function
def animate_l(i):
    ln1_l.set_data([0, x1_lv[i], x2_lv[i]], [0, y1_lv[i], y2_lv[i]])

# Create the figure and axis
fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_facecolor('k')
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])

# Create lines for both pendulums with labels
ln1_nl, = plt.plot([], [], 'bo--', lw=3, markersize=8, label='Nonlinear Pendulum')  # Blue line for first pendulum
ln1_l, = plt.plot([], [], 'ro--', lw=3, markersize=8, label='Linear Pendulum')       # Red line for second pendulum

# Set limits for the plot
ax.set_ylim(-4,4)
ax.set_xlim(-4,4)

# Animate both pendulums
def animate(i):
    animate_nl(i)
    animate_l(i)

ani = animation.FuncAnimation(fig, animate, frames=1000, interval=50)

# Add legend
ax.legend()

# Add title
ax.set_title('Combined Animation of Linear and Nonlinear Double Pendulums')

# Save the combined animation
ani.save('gifs/comparison-large-angles.gif', writer='pillow', fps=25)
